# %% [markdown]
# # Calculating eigenvalues for problem 2 of homework 3

# %%
from sympy import *
init_printing(use_unicode=True)

# %%
M = Matrix([[-1, 0,], [-2,  -2,]])
M
# Out:
# ⎡-1  0 ⎤
# ⎢      ⎥
# ⎣-2  -2⎦

# %%
M.eigenvals()
# Out:
# {-2: 1, -1: 1}

# %%
M = Matrix([[-1, -2,], [-1,  -1,]])
M
# Out:
# ⎡-1  -2⎤
# ⎢      ⎥
# ⎣-1  -1⎦

# %%
M.eigenvals()
# Out:
# {-1 + √2: 1, -√2 - 1: 1}
