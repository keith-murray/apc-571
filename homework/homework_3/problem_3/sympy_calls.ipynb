# %% [markdown]
# # Calculating eigenvectors and eigenvalues for problem 3 of homework 3

# %%
from sympy import *
init_printing(use_unicode=True)

# %%
x = symbols('delta')

# %%
M = Matrix([[0, 1,], [-1,  -x,]])
M
# Out:
# ⎡0   1 ⎤
# ⎢      ⎥
# ⎣-1  -δ⎦

# %%
M.eigenvects()
# Out:
# ⎡⎛                              ⎡⎡        _________________⎤⎤⎞  ⎛              ↪
# ⎢⎜        _________________     ⎢⎢  δ   ╲╱ (δ - 2)⋅(δ + 2) ⎥⎥⎟  ⎜        _____ ↪
# ⎢⎜  δ   ╲╱ (δ - 2)⋅(δ + 2)      ⎢⎢- ─ + ───────────────────⎥⎥⎟  ⎜  δ   ╲╱ (δ - ↪
# ⎢⎜- ─ - ───────────────────, 1, ⎢⎢  2            2         ⎥⎥⎟, ⎜- ─ + ─────── ↪
# ⎢⎜  2            2              ⎢⎢                         ⎥⎥⎟  ⎜  2           ↪
# ⎣⎝                              ⎣⎣            1            ⎦⎦⎠  ⎝              ↪
#
# ↪                  ⎡⎡        _________________⎤⎤⎞⎤
# ↪ ____________     ⎢⎢  δ   ╲╱ (δ - 2)⋅(δ + 2) ⎥⎥⎟⎥
# ↪  2)⋅(δ + 2)      ⎢⎢- ─ - ───────────────────⎥⎥⎟⎥
# ↪ ────────────, 1, ⎢⎢  2            2         ⎥⎥⎟⎥
# ↪   2              ⎢⎢                         ⎥⎥⎟⎥
# ↪                  ⎣⎣            1            ⎦⎦⎠⎦

# %%
print(latex(M.eigenvects()))
# Out:
# \left[ \left( - \frac{\delta}{2} - \frac{\sqrt{\left(\delta - 2\right) \left(\delta + 2\right)}}{2}, \  1, \  \left[ \left[\begin{matrix}- \frac{\delta}{2} + \frac{\sqrt{\left(\delta - 2\right) \left(\delta + 2\right)}}{2}\\1\end{matrix}\right]\right]\right), \  \left( - \frac{\delta}{2} + \frac{\sqrt{\left(\delta - 2\right) \left(\delta + 2\right)}}{2}, \  1, \  \left[ \left[\begin{matrix}- \frac{\delta}{2} - \frac{\sqrt{\left(\delta - 2\right) \left(\delta + 2\right)}}{2}\\1\end{matrix}\right]\right]\right)\right]
