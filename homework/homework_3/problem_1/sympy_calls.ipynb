# %% [markdown]
# # Calculating eigenvectors and eigenvalues for problem 1 of homework 3

# %%
from sympy import *
init_printing(use_unicode=True)

# %% [markdown]
# ## Part A

# %% [markdown]
# ### First case

# %%
x = symbols('delta')

# %%
M = Matrix([[0, 1,], [0,  -x,]])
M
# Out:
# ⎡0  1 ⎤
# ⎢     ⎥
# ⎣0  -δ⎦

# %%
M.eigenvects()
# Out:
# ⎡               ⎛       ⎡⎡-1 ⎤⎤⎞⎤
# ⎢⎛      ⎡⎡1⎤⎤⎞  ⎜       ⎢⎢───⎥⎥⎟⎥
# ⎢⎜0, 1, ⎢⎢ ⎥⎥⎟, ⎜-δ, 1, ⎢⎢ δ ⎥⎥⎟⎥
# ⎢⎝      ⎣⎣0⎦⎦⎠  ⎜       ⎢⎢   ⎥⎥⎟⎥
# ⎣               ⎝       ⎣⎣ 1 ⎦⎦⎠⎦

# %%
print(latex(M.eigenvects()))
# Out:
# \left[ \left( 0, \  1, \  \left[ \left[\begin{matrix}1\\0\end{matrix}\right]\right]\right), \  \left( - \delta, \  1, \  \left[ \left[\begin{matrix}- \frac{1}{\delta}\\1\end{matrix}\right]\right]\right)\right]

# %% [markdown]
# ### Second case

# %%
x, y = symbols('beta delta')

# %%
M = Matrix([[0, 1,], [-sqrt(1-x**2),  -y,]])
M
# Out:
# ⎡     0        1 ⎤
# ⎢                ⎥
# ⎢    ________    ⎥
# ⎢   ╱      2     ⎥
# ⎣-╲╱  1 - β    -δ⎦

# %%
M.eigenvects()
# Out:
# ⎡⎛                                   ⎡⎡                          _____________ ↪
# ⎢⎜                                   ⎢⎢                         ╱           __ ↪
# ⎢⎜          ____________________     ⎢⎢                        ╱   2       ╱   ↪
# ⎢⎜         ╱           ________      ⎢⎢                  δ   ╲╱   δ  - 4⋅╲╱  1 ↪
# ⎢⎜        ╱   2       ╱      2       ⎢⎢                - ─ - ───────────────── ↪
# ⎢⎜  δ   ╲╱   δ  - 4⋅╲╱  1 - β        ⎢⎢       δ          2              2      ↪
# ⎢⎜- ─ - ────────────────────────, 1, ⎢⎢- ─────────── - ─────────────────────── ↪
# ⎢⎜  2              2                 ⎢⎢     ________               ________    ↪
# ⎢⎜                                   ⎢⎢    ╱      2               ╱      2     ↪
# ⎢⎜                                   ⎢⎢  ╲╱  1 - β              ╲╱  1 - β      ↪
# ⎢⎜                                   ⎢⎢                                        ↪
# ⎣⎝                                   ⎣⎣                      1                 ↪
#
# ...

# %%
print(latex(M.eigenvects()))
# Out:
# \left[ \left( - \frac{\delta}{2} - \frac{\sqrt{\delta^{2} - 4 \sqrt{1 - \beta^{2}}}}{2}, \  1, \  \left[ \left[\begin{matrix}- \frac{\delta}{\sqrt{1 - \beta^{2}}} - \frac{- \frac{\delta}{2} - \frac{\sqrt{\delta^{2} - 4 \sqrt{1 - \beta^{2}}}}{2}}{\sqrt{1 - \beta^{2}}}\\1\end{matrix}\right]\right]\right), \  \left( - \frac{\delta}{2} + \frac{\sqrt{\delta^{2} - 4 \sqrt{1 - \beta^{2}}}}{2}, \  1, \  \left[ \left[\begin{matrix}- \frac{\delta}{\sqrt{1 - \beta^{2}}} - \frac{- \frac{\delta}{2} + \frac{\sqrt{\delta^{2} - 4 \sqrt{1 - \beta^{2}}}}{2}}{\sqrt{1 - \beta^{2}}}\\1\end{matrix}\right]\right]\right)\right]

# %% [markdown]
# ## Third case

# %%
x, y = symbols('beta delta')

# %%
M = Matrix([[0, 1,], [sqrt(1-x**2),  -y,]])
M
# Out:
# ⎡     0       1 ⎤
# ⎢               ⎥
# ⎢   ________    ⎥
# ⎢  ╱      2     ⎥
# ⎣╲╱  1 - β    -δ⎦

# %%
M.eigenvects()
# Out:
# ⎡⎛                                   ⎡⎡                        _______________ ↪
# ⎢⎜                                   ⎢⎢                       ╱           ____ ↪
# ⎢⎜          ____________________     ⎢⎢                      ╱   2       ╱     ↪
# ⎢⎜         ╱           ________      ⎢⎢                δ   ╲╱   δ  + 4⋅╲╱  1 - ↪
# ⎢⎜        ╱   2       ╱      2       ⎢⎢              - ─ - ─────────────────── ↪
# ⎢⎜  δ   ╲╱   δ  + 4⋅╲╱  1 - β        ⎢⎢     δ          2              2        ↪
# ⎢⎜- ─ - ────────────────────────, 1, ⎢⎢─────────── + ───────────────────────── ↪
# ⎢⎜  2              2                 ⎢⎢   ________               ________      ↪
# ⎢⎜                                   ⎢⎢  ╱      2               ╱      2       ↪
# ⎢⎜                                   ⎢⎢╲╱  1 - β              ╲╱  1 - β        ↪
# ⎢⎜                                   ⎢⎢                                        ↪
# ⎣⎝                                   ⎣⎣                     1                  ↪
#
# ...
