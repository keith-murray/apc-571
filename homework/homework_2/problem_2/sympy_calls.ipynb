# %% [markdown]
# # Calculating eigenvectors and eigenvalues for problem 2 of homework 2

# %%
from sympy import *
init_printing(use_unicode=True)

# %% [markdown]
# ## Part A

# %%
M = Matrix([[1, -3, 3,], [3,  -5, 3,], [6,  -6, 4,]])
M
# Out:
# ⎡1  -3  3⎤
# ⎢        ⎥
# ⎢3  -5  3⎥
# ⎢        ⎥
# ⎣6  -6  4⎦

# %%
M.eigenvects()
# Out:
# ⎡⎛       ⎡⎡1⎤  ⎡-1⎤⎤⎞  ⎛      ⎡⎡1/2⎤⎤⎞⎤
# ⎢⎜       ⎢⎢ ⎥  ⎢  ⎥⎥⎟  ⎜      ⎢⎢   ⎥⎥⎟⎥
# ⎢⎜-2, 2, ⎢⎢1⎥, ⎢0 ⎥⎥⎟, ⎜4, 1, ⎢⎢1/2⎥⎥⎟⎥
# ⎢⎜       ⎢⎢ ⎥  ⎢  ⎥⎥⎟  ⎜      ⎢⎢   ⎥⎥⎟⎥
# ⎣⎝       ⎣⎣0⎦  ⎣1 ⎦⎦⎠  ⎝      ⎣⎣ 1 ⎦⎦⎠⎦

# %% [markdown]
# ## Part B

# %%
x = symbols('lambda')

# %%
M = Matrix([[1, -1,], [0,  x,]])
M
# Out:
# ⎡1  -1⎤
# ⎢     ⎥
# ⎣0  λ ⎦

# %%
M.eigenvects()
# Out:
# ⎡               ⎛      ⎡⎡ -1  ⎤⎤⎞⎤
# ⎢⎛      ⎡⎡1⎤⎤⎞  ⎜      ⎢⎢─────⎥⎥⎟⎥
# ⎢⎜1, 1, ⎢⎢ ⎥⎥⎟, ⎜λ, 1, ⎢⎢λ - 1⎥⎥⎟⎥
# ⎢⎝      ⎣⎣0⎦⎦⎠  ⎜      ⎢⎢     ⎥⎥⎟⎥
# ⎣               ⎝      ⎣⎣  1  ⎦⎦⎠⎦

# %%
print(latex(M.eigenvects()))
# Out:
# \left[ \left( 1, \  1, \  \left[ \left[\begin{matrix}1\\0\end{matrix}\right]\right]\right), \  \left( \lambda, \  1, \  \left[ \left[\begin{matrix}- \frac{1}{\lambda - 1}\\1\end{matrix}\right]\right]\right)\right]
