# %% [markdown]
# # Stream plots for systems in problem 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Part A

# %%
fig, axs = plt.subplots(2, 3, figsize=(12, 6),)
axs = axs.flat

## Positive epsilon
eps = 4.5
w = 2
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = Y
V = X - X**3 - eps*Y
speed = np.sqrt(U**2 + V**2)

strm = axs[0].streamplot(X, Y, U, V, density=[0.5, 1], color=speed, cmap='autumn')
axs[0].set_title(f'Epsilon of {eps}')

## Positive epsilon
eps = 0.5
w = 2
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = Y
V = X - X**3 - eps*Y
speed = np.sqrt(U**2 + V**2)

strm = axs[1].streamplot(X, Y, U, V, density=[0.5, 1], color=speed, cmap='autumn')
axs[1].set_title(f'Epsilon of {eps}')

## Zero epsilon
eps = 0.0
w = 2
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = Y
V = X - X**3 - eps*Y
speed = np.sqrt(U**2 + V**2)

strm = axs[2].streamplot(X, Y, U, V, density=[0.5, 1], color=speed, cmap='autumn')
axs[2].set_title(f'Epsilon of {eps}')

## Negative epsilon
eps = -0.5
w = 2
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = Y
V = X - X**3 - eps*Y
speed = np.sqrt(U**2 + V**2)

strm = axs[3].streamplot(X, Y, U, V, density=[0.5, 1], color=speed, cmap='autumn')
axs[3].set_title(f'Epsilon of {eps}')

## Negative epsilon
eps = -4.5
w = 2
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = Y
V = X - X**3 - eps*Y
speed = np.sqrt(U**2 + V**2)

strm = axs[4].streamplot(X, Y, U, V, density=[0.5, 1], color=speed, cmap='autumn')
axs[4].set_title(f'Epsilon of {eps}')

axs[5].set_visible(False)

plt.tight_layout()
plt.savefig('./figures/problem_1_a.png')
plt.show()

# %% [markdown]
# ## Part B

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 6),)
axs = axs.flat

## Positive epsilon
eps = 0.5
w = 5
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = Y
V = - np.sin(X) - eps*Y**3
speed = np.sqrt(U**2 + V**2)

strm = axs[0].streamplot(X, Y, U, V, density=[0.5, 1], color=speed, cmap='autumn')
axs[0].set_title(f'Epsilon of {eps}')

## Zero epsilon
eps = 0.0
w = 5
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = Y
V = - np.sin(X) - eps*Y**3
speed = np.sqrt(U**2 + V**2)

strm = axs[1].streamplot(X, Y, U, V, density=[0.5, 1], color=speed, cmap='autumn')
axs[1].set_title(f'Epsilon of {eps}')

## Negative epsilon
eps = -0.5
w = 5
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = Y
V = - np.sin(X) - eps*Y**3
speed = np.sqrt(U**2 + V**2)

strm = axs[2].streamplot(X, Y, U, V, density=[0.5, 1], color=speed, cmap='autumn')
axs[2].set_title(f'Epsilon of {eps}')

axs[3].set_visible(False)

plt.tight_layout()
plt.savefig('./figures/problem_1_b.png')
plt.show()

# %% [markdown]
# ## Part C

# %%
fig, axs = plt.subplots(1, 1, figsize=(4, 3),)

w = 3
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = -X + X**2
V = X + Y
speed = np.sqrt(U**2 + V**2)

strm = axs.streamplot(X, Y, U, V, density=[0.5, 1], color=speed, cmap='autumn')

plt.tight_layout()
plt.savefig('./figures/problem_1_c.png')
plt.show()
